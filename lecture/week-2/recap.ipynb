# %% [markdown]
# # Week 1 Recap: print, input, and booleans

# %% [markdown]
# Print function refresh
# * Combining strings and printing variables
# * "sep"

# %%
name_1 = "Isabel"
name_2 = "Harrison"
name_3 = "Yeri"

print(name_1 + name_2 + name_3)
# Out:
# IsabelHarrisonYeri

# %%
print(name_1,name_2,name_3)
# Out:
# Isabel Harrison Yeri

# %%
print(name_1,name_2,name_3,sep=";")
print(name_1,name_2,name_3,sep=", ")
# Out:
# Isabel;Harrison;Yeri
# Isabel, Harrison, Yeri

# %%
print(name_1,name_2,"and",name_3)
# Out:
# Isabel Harrison and Yeri

# %%
print("You can print a sentence by itself")
# Out:
# You can print a sentence by itself

# %%
print("You can print combinations","of strings and variables",name_2)
# Out:
# You can print combinations of strings and variables Harrison

# %% [markdown]
# Input function refresh
# * storing inputs as variables
# * printing inputs

# %%
name = input("Provide a name here")

# %%
age = 65

print(name_1 + str(age))
# Out:
# Isabel65

# %%
## seperating code across multiple lines

print('''you can print a string
      with triple quotes''')
# Out:
# you can print a string
#       with triple quotes

# %% [markdown]
# Booleans
# * As you'll recall, boolean variables take on one of two value: True or False.
#   * We create booleans by performing comparisons on other expressions.
#   * We use the == operator to test whether two expressions are equal.
#   * We use the != to test whether they're not equal.
#   * For numbers, we can also use >, <, <=, and >= to compare whethether something is bigger or smaller.
#   * We also have compound boolean operators like `and`, `or`, and `not` that allow us to build bigger logical expressions.
#
# Activities:
# * Write a simple program to tell me whether I need to wear a jacket
# * Wear a jacket if it's raining or if it's below 65 degrees

# %%
cold = True
raining = False

# Check if we need to wear a jacket
wear_a_jacket = cold or raining

print("Wear a jacket:",wear_a_jacket)
# Out:
# Wear a jacket: True

# %%
cold = False
raining = True

# Check if we need to wear a jacket
wear_a_jacket = cold and raining

print("Wear a jacket:",wear_a_jacket)
# Out:
# Wear a jacket: False

# %%
dont_need_a_jacket = ((not raining) and (not cold))
print(dont_need_a_jacket)
# Out:
# True

# %% [markdown]
# Git commands refresh
# - open files
# - commiting and pushing
