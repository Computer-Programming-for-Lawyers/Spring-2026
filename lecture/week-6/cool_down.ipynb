# %% [markdown]
# Without actually running them, predict what each of the following code snippets will do when run.

# %%
def f(x):
	return x ** x

# %%
def g(x):
	return x
	return x ** x
	return x ** x ** x
	
print(g(3))

# %%
def h(x):
	x = x + 1
	return x
	
x = 3
print(h(x))
print(x)
