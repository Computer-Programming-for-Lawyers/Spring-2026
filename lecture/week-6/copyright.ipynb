# %%
import helper

import importlib
importlib.reload(helper)
# Out:
# <module 'helper' from '/Users/rachelorey/Documents/vs code/Spring-2026/lecture/week-6/helper.py'>

# %%
while True:
    # Date of publication.

    year = helper.validate("In what year was the work published? ",1923,2026)
    month = helper.validate("In what month was the work published? ",1,12)
    day = helper.validate("On what day of the month was the work published?",1,31)


    # year = int(input("In what year was the work published? ")
    # while year < 1923: #assume upperbound of 2026
    #     print("The year input must be a number greater than 1922.")
    #     year = int(input("In what year was the work published? "))


    # month = int(input("In what month was the work published? "))
    # while month > 12 or month < 1:
    #     print("The month input must be a number between 1 and 12.")
    #     month = int(input("In what month was the work published? "))
    

    # day = int(input("On what day of the month was the work published? "))
    # while day > 31 or day < 1:
    #     print("The day input must be a number between 1 and 31.")
    #     day = int(input("On what day of the month was the work published? "))

    # Other questions.
    notice_in  = input("Was notice of copyright given? ")
    renewed_in = input("Was the work properly renewed (manually or automatically)? ")
    expired_in = input("Has the original term of copyright protection expired? ")

    # check wither inputs are in list of valid yeses
    noticed = helper.parse_yn(notice_in)
    renewed = helper.parse_yn(renewed_in)
    expired = helper.parse_yn(expired_in)

    # Execute the flowchart.
    if year >= 2003:
        if not expired:
            print('In Copyright')
        else:
            print('In Public Domain')

    elif year >= 1989 and month >= 3:
        print('In Copyright')

    elif year >= 1978:
        if noticed:
            print('In Copyright')
        else:
            print('In Public Domain')

    elif year >= 1964:
        if expired or not noticed:
            print('In Public Domain')
        else:
            print('In Copyright')

    else:
        if expired or not renewed or not noticed:
            print('In Public Domain')
        else:
            print('In Copyright')

    print()
    
    go_again = input("Do you want to analyze another work? ")
    if not helper.parse_yn(go_again):
        break
        
print("Goodbye!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 while True:
#       2     # Date of publication.
# ----> 4     year = helper.validate("In what year was the work published? ",1923,2026)
#       5     month = helper.validate("In what month was the work published? ",1,12)
#       6     day = helper.validate("On what day of the month was the work published?",1,31)
#
# File ~/Documents/vs code/Spring-2026/lecture/week-6/helper.py:22, in validate(input_prompt, lower_bound, upper_bound)
#      14 def validate(input_prompt: str, lower_bound: int, upper_bound: int):
#      15     """
#      16     Takes as an input a string for a user input prompt.
#      17     Also takes as an input the lower and upper bound of the user's response.
#      18     If the user's response is outside of that range, it continues to ask the user to submit
#      19     another input until the input is correct.
#      20     """
# ---> 22     answer = int(input(input_prompt))
#      24     while not (lower_bound <= answer <= upper_bound):
#      25         print(f"Your value must be between {lower_bound} and {upper_bound}. Try again.")
#
# ValueError: invalid literal for int() with base 10: ''
